# %%
plt.plot

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

def data_reader ( file):
    return pd.read_csv(file)

datar=data_reader(r"c:\Users\Humair Munir\Desktop\GPT_reviews.csv")


def hist_plot_factory(hist_data , bin = "",title = "" , xlabel ="" , ylabel = " " , color ="" ):
    plt.hist(hist_data , bin ,color=color)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

def scatter_plot_factory(x_data , y_data , s = "" , alpha = '',title = "" , xlabel ="" , ylabel = " " , color ="" ):
    plt.scatter(x_data , y_data , s=s , alpha = alpha,color=color)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()


data = datar["Rating"]
data1 = datar['Thumbs Up']
s = 50
alp = 0.7
title  = "rating vs thumbs up"
xlabel = " rating"
ylabel = 'thumbs up'
col = "red"

#scatter_plot_factory(data , data1 ,  s , alp,title , xlabel , ylabel , col )

# %%
class Plot_Foctory:
    def hist_plot_factory(hist_data , bin = "",title = "" , xlabel ="" , ylabel = " " , color ="" ):
      plt.hist(hist_data , bin ,color=color)
      plt.title(title)
      plt.xlabel(xlabel)
      plt.ylabel(ylabel)
      plt.show()
    def scatter_plot_factory(x_data , y_data , s = "" , alpha = '',title = "" , xlabel ="" , ylabel = " " , color ="" ):
        plt.scatter(x_data , y_data , s=s , alpha = alpha,color=color)
        plt.title(title)
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.show()


data = datar["Rating"]
data1 = datar['Thumbs Up']
s = 10
alp = 0.7
title  = "rating vs thumbs up"
xlabel = " rating"
ylabel = 'thumbs up'
col = "red"

Plot_Foctory.hist_plot_factory(data ,   s ,title , xlabel , ylabel , col )
